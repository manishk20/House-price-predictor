# %%
import numpy as np
si = np.random.permutation(5)
si
# Out:
# array([4, 3, 1, 0, 2])

# %%
a=np.array([4,5,2,6,7])

# %%
b=a[si]

# %%
b
# Out:
# array([7, 6, 5, 4, 2])

# %%
b==7
# Out:
# array([ True, False, False, False, False])
